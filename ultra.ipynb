# %%
import ultralytics as ut
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\HP\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
import cv2 
model = YOLO("yolo11n.pt")
predict_class= [0,14]
img = 'demo1.avif'
pred= model(img ,classes= predict_class, conf=0.4)
pred_img= pred[0].plot()
cv2.imwrite("we.jpg", pred_img)
# Out:
# image 1/1 c:\Users\HP\OneDrive\Documents\Internship\demo1.avif: 640x448 7 persons, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# True
