# %%
import math
from sklearn.feature_extraction.text import TfidfVectorizer

doc = ['AI is amazing','AI is changing world','Machine learning is amazing']
tfidf = TfidfVectorizer()
result = tfidf.fit_transform(doc)
print(tfidf.get_feature_names_out())
print(result)
# Out:
# ['ai' 'amazing' 'changing' 'is' 'learning' 'machine' 'world']
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 11 stored elements and shape (3, 7)>
#   Coords	Values
#   (0, 0)	0.6198053799406072
#   (0, 3)	0.48133416873660545
#   (0, 1)	0.6198053799406072
#   (1, 0)	0.444514311537431
#   (1, 3)	0.34520501686496574
#   (1, 2)	0.5844829010200651
#   (1, 6)	0.5844829010200651
#   (2, 3)	0.34520501686496574
#   (2, 1)	0.444514311537431
#   (2, 5)	0.5844829010200651
#   (2, 4)	0.5844829010200651

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

text = """I am a Data Science student"""
sent_tokenize(text)
# Out:
# ['I am a Data Science student']

# %%
from nltk.tokenize import word_tokenize

text = """I am a Data Science student"""
word_tokenize(text)
# Out:
# ['I', 'am', 'a', 'Data', 'Science', 'student']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
text= """Artificial Intelligence is changing the world. It helps solve many problems. Python is a popular programming language for AI."""
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(text)

filtered_sentence = []
for w in word_tokens:

    if w not in stop_words:
        filtered_sentence.append(w)
        print(filtered_sentence)
# Out:
# ['Artificial']
# ['Artificial', 'Intelligence']
# ['Artificial', 'Intelligence', 'changing']
# ['Artificial', 'Intelligence', 'changing', 'world']
# ['Artificial', 'Intelligence', 'changing', 'world', '.']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve', 'many']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve', 'many', 'problems']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve', 'many', 'problems', '.']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve', 'many', 'problems', '.', 'Python']
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'It', 'helps', 'solve', 'many', 'problems', '.', 'Python', 'popular']
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download resources (run only once)
nltk.download('punkt')
nltk.download('stopwords')

text = """Artificial Intelligence is changing the world. It helps solve many problems. Python is a popular programming language for AI."""

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(text)

filtered_sentence = []

for w in word_tokens:
    if w.lower() not in stop_words:
        filtered_sentence.append(w)

print("Original Words:")
print(word_tokens)

print("\nAfter Removing Stop Words:")
print(filtered_sentence)
# Out:
# Original Words:
# ['Artificial', 'Intelligence', 'is', 'changing', 'the', 'world', '.', 'It', 'helps', 'solve', 'many', 'problems', '.', 'Python', 'is', 'a', 'popular', 'programming', 'language', 'for', 'AI', '.']
#
# After Removing Stop Words:
# ['Artificial', 'Intelligence', 'changing', 'world', '.', 'helps', 'solve', 'many', 'problems', '.', 'Python', 'popular', 'programming', 'language', 'AI', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language = "english")
word = "civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()
print(f"better/n Stemming:{porter.stem('better')}/n Lemmatization: { lemmatizer.lemmatize('better', pos = 'a')}")
# Out:
# better/n Stemming:better/n Lemmatization: good

# %%
from nltk.stem import SnowballStemmer , LancasterStemmer
sentence = "It is good to be a pythoner who is pythonly pythoning with python"
words = nltk.word_tokenize(sentence)
for word in words:
    lanc = LancasterStemmer()
    print(lanc.stem(word))
# Out:
# it
# is
# good
# to
# be
# a
# python
# who
# is
# python
# python
# with
# python
